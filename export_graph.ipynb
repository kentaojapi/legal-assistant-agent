# %%
import io

from IPython.display import Image

from workflow import ContractAgent

graph_png = ContractAgent().graph.get_graph().draw_png()

with open('./image/graph.png', 'wb') as f:
    f.write(graph_png)

Image(graph_png)

# %%
import io

from IPython.display import Image

from react import ReactAgent

react_graph_png = ReactAgent().agent.get_graph().draw_png()

with open('./image/react.png', 'wb') as f:
    f.write(react_graph_png)

Image(react_graph_png)
